# %%
import pandas as pd

matematicas = pd.read_csv("student-mat.csv", sep=";")
portugues = pd.read_csv("student-por.csv", sep=";")

matematicas
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
# ...

# %%
matematicas["asignatura"] = "matematicas"
portugues["asignatura"] = "portugues"
estudiantes = pd.concat([matematicas, portugues], ignore_index=True)

estudiantes
# Out:
#      school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0        GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1        GP   F   17       U     GT3       T     1     1   at_home     other
# 2        GP   F   15       U     LE3       T     1     1   at_home     other
# 3        GP   F   15       U     GT3       T     4     2    health  services
# 4        GP   F   16       U     GT3       T     3     3     other     other
# ...     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 1039     MS   F   19       R     GT3       T     2     3  services     other
# 1040     MS   F   18       U     LE3       T     3     1   teacher  services
# 1041     MS   F   18       U     GT3       T     1     1     other     other
# 1042     MS   M   17       U     LE3       T     3     1  services  services
# 1043     MS   M   18       R     LE3       T     3     2  services     other
#
# ...

# %%
from datetime import datetime
fecha = datetime.now().strftime("%d-%m-%Y")

fecha
# Out:
# '26-10-2022'

# %%
estudiantes = estudiantes.dropna()

estudiantes
# Out:
#      school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0        GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1        GP   F   17       U     GT3       T     1     1   at_home     other
# 2        GP   F   15       U     LE3       T     1     1   at_home     other
# 3        GP   F   15       U     GT3       T     4     2    health  services
# 4        GP   F   16       U     GT3       T     3     3     other     other
# ...     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 1039     MS   F   19       R     GT3       T     2     3  services     other
# 1040     MS   F   18       U     LE3       T     3     1   teacher  services
# 1041     MS   F   18       U     GT3       T     1     1     other     other
# 1042     MS   M   17       U     LE3       T     3     1  services  services
# 1043     MS   M   18       R     LE3       T     3     2  services     other
#
# ...

# %%
nombrecolegio_curso = estudiantes[["school", "sex", "age", "address", "Pstatus", "guardian", "traveltime", "studytime", "failures", "paid", "internet", "health", "absences", "G1", "G2", "G3"]]
nombrecolegio_curso
# Out:
#      school sex  age address Pstatus guardian  traveltime  studytime  \
# 0        GP   F   18       U       A   mother           2          2
# 1        GP   F   17       U       T   father           1          2
# 2        GP   F   15       U       T   mother           1          2
# 3        GP   F   15       U       T   mother           1          3
# 4        GP   F   16       U       T   father           1          2
# ...     ...  ..  ...     ...     ...      ...         ...        ...
# 1039     MS   F   19       R       T   mother           1          3
# 1040     MS   F   18       U       T   mother           1          2
# 1041     MS   F   18       U       T   mother           2          2
# 1042     MS   M   17       U       T   mother           2          1
# 1043     MS   M   18       R       T   mother           3          1
#
#       failures paid internet  health  absences  G1  G2  G3
# 0            0   no       no       3         6   5   6   6
# ...

# %%
escuela1 = nombrecolegio_curso[nombrecolegio_curso["school"] == "GP"]
escuela2 = nombrecolegio_curso[nombrecolegio_curso["school"] == "MS"]

escuela1
# Out:
#     school sex  age address Pstatus guardian  traveltime  studytime  failures  \
# 0       GP   F   18       U       A   mother           2          2         0
# 1       GP   F   17       U       T   father           1          2         0
# 2       GP   F   15       U       T   mother           1          2         3
# 3       GP   F   15       U       T   mother           1          3         0
# 4       GP   F   16       U       T   father           1          2         0
# ..     ...  ..  ...     ...     ...      ...         ...        ...       ...
# 813     GP   M   18       R       T   father           1          1         0
# 814     GP   M   19       U       T   mother           1          1         0
# 815     GP   F   18       U       A   mother           2          2         0
# 816     GP   F   20       U       T   mother           2          1         1
# 817     GP   F   18       U       T   mother           1          2         0
#
# ...

# %%
escuela2
# Out:
#      school sex  age address Pstatus guardian  traveltime  studytime  \
# 349      MS   M   18       R       T   mother           2          1
# 350      MS   M   19       R       T    other           3          2
# 351      MS   M   17       U       T   mother           2          2
# 352      MS   M   18       U       T   mother           1          1
# 353      MS   M   19       R       T    other           3          1
# ...     ...  ..  ...     ...     ...      ...         ...        ...
# 1039     MS   F   19       R       T   mother           1          3
# 1040     MS   F   18       U       T   mother           1          2
# 1041     MS   F   18       U       T   mother           2          2
# 1042     MS   M   17       U       T   mother           2          1
# 1043     MS   M   18       R       T   mother           3          1
#
#       failures paid internet  health  absences  G1  G2  G3
# 349          1   no      yes       5        10  11  13  13
# ...

# %%
escuela1["sex"].value_counts().plot(kind="pie", autopct="%0.1f %%")
# Out:
# <AxesSubplot:ylabel='sex'>

# %%
escuela2["sex"].value_counts().plot(kind="pie", autopct="%0.1f %%")
# Out:
# <AxesSubplot:ylabel='sex'>

# %%
escuela1["age"].value_counts().plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
escuela2["age"].value_counts().plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
escuela1[["age", "traveltime", "studytime", "failures", "health", "absences"]].groupby("age").mean()
# Out:
#      traveltime  studytime  failures    health   absences
# age
# 15     1.375000   2.136905  0.142857  3.559524   3.083333
# 16     1.421296   1.870370  0.166667  3.689815   4.453704
# 17     1.438424   2.029557  0.221675  3.674877   5.679803
# 18     1.404255   2.191489  0.269504  3.347518   6.000000
# 19     1.371429   2.085714  0.800000  3.600000   9.028571
# 20     1.600000   1.600000  0.600000  4.000000   4.200000
# 21     1.500000   2.500000  2.000000  4.500000  10.500000
# 22     1.000000   1.000000  3.000000  1.000000  14.000000

# %%
escuela2[["age", "traveltime", "studytime", "failures", "health", "absences"]].groupby("age").mean()
# Out:
#      traveltime  studytime  failures    health  absences
# age
# 15     1.961538   1.653846  0.076923  3.307692  3.192308
# 16     1.800000   1.876923  0.138462  3.307692  1.984615
# 17     1.743243   1.702703  0.243243  3.432432  2.851351
# 18     1.950617   1.839506  0.320988  3.518519  2.901235
# 19     1.809524   1.714286  1.333333  3.428571  3.285714
# 20     1.750000   2.000000  1.500000  3.500000  8.750000
# 21     1.000000   1.000000  3.000000  3.000000  3.000000

# %%
estudiantes[["school", "G1", "G2", "G3"]].groupby("school").mean()
# Out:
#                G1         G2         G3
# school
# GP      11.512953  11.528497  11.633420
# MS      10.363971  10.444853  10.514706

# %%
estudiantes[["school", "G1", "G2", "G3"]].groupby("school").mean().plot(kind="barh")
# Out:
# <AxesSubplot:ylabel='school'>

# %%
total_clases1 = escuela1[["school", "absences"]].groupby("school").max()
escuela1[["school", "absences"]].groupby("school")

# %%
total_clases2 = escuela2[["school", "absences"]].groupby("school").max()
escuela2[["school", "absences"]].groupby("school").max()
# Out:
#         absences
# school
# MS            17

# %%
estudiantes["extra"] = estudiantes["absences"] * 100 / 93

estudiantes
# Out:
#      school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0        GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1        GP   F   17       U     GT3       T     1     1   at_home     other
# 2        GP   F   15       U     LE3       T     1     1   at_home     other
# 3        GP   F   15       U     GT3       T     4     2    health  services
# 4        GP   F   16       U     GT3       T     3     3     other     other
# ...     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 1039     MS   F   19       R     GT3       T     2     3  services     other
# 1040     MS   F   18       U     LE3       T     3     1   teacher  services
# 1041     MS   F   18       U     GT3       T     1     1     other     other
# 1042     MS   M   17       U     LE3       T     3     1  services  services
# 1043     MS   M   18       R     LE3       T     3     2  services     other
#
# ...

# %%
def approved(row):
    if row["extra"] < 80:
        return "Reprobado"
    elif row["extra"] >= 80 and row["G3"] < 10:
        return "Reprobado"
    elif row["extra"] >= 80 and row["G3"] >= 10 and row["G3"] <= 15:
        return "Aprobado"
    elif row["extra"] >= 80 and row["G3"] > 15:
        return "Aprobado"

estudiantes["approved"] = estudiantes.apply(approved, axis=1)
estudiantes
# Out:
#      school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0        GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1        GP   F   17       U     GT3       T     1     1   at_home     other
# 2        GP   F   15       U     LE3       T     1     1   at_home     other
# 3        GP   F   15       U     GT3       T     4     2    health  services
# 4        GP   F   16       U     GT3       T     3     3     other     other
# ...     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 1039     MS   F   19       R     GT3       T     2     3  services     other
# 1040     MS   F   18       U     LE3       T     3     1   teacher  services
# 1041     MS   F   18       U     GT3       T     1     1     other     other
# 1042     MS   M   17       U     LE3       T     3     1  services  services
# 1043     MS   M   18       R     LE3       T     3     2  services     other
#
# ...

# %%
estudiantes["approved"] = estudiantes.apply(approved, axis=1)


estudiantes
# Out:
#      school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0        GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1        GP   F   17       U     GT3       T     1     1   at_home     other
# 2        GP   F   15       U     LE3       T     1     1   at_home     other
# 3        GP   F   15       U     GT3       T     4     2    health  services
# 4        GP   F   16       U     GT3       T     3     3     other     other
# ...     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 1039     MS   F   19       R     GT3       T     2     3  services     other
# 1040     MS   F   18       U     LE3       T     3     1   teacher  services
# 1041     MS   F   18       U     GT3       T     1     1     other     other
# 1042     MS   M   17       U     LE3       T     3     1  services  services
# 1043     MS   M   18       R     LE3       T     3     2  services     other
#
# ...

# %%
estudiantes["approved"].value_counts().plot(kind="pie", autopct="%0.1f %%")
# Out:
# <AxesSubplot:ylabel='approved'>

# %%
estudiantes.to_csv("Resultado" + fecha + ".csv", index=False)
