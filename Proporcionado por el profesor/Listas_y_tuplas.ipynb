# %% [markdown]
# <img src="![Comparacion](attachment:Captura%20de%20Pantalla%202022-08-22%20a%20la%28s%29%206.51.22%20p.%C2%A0m..png)"

# %% [markdown]
# # Lista

# %%
Lista = ['un', 'ejemplo', 'de', 'una', 'lista']
print(Lista)
type(Lista)
Lista.sort()
print(Lista)
# Out:
# ['un', 'ejemplo', 'de', 'una', 'lista']
# ['de', 'ejemplo', 'lista', 'un', 'una']

# %% [markdown]
# # Tupla

# %%
tupla = ('esta', 'es', 'un', 'ejemplo', 'de', 'tupla')
print(tupla)
type(tupla)
tuplaOrd = sorted(tupla)
print(tupla)
print(tuplaOrd)
# Out:
# ('esta', 'es', 'un', 'ejemplo', 'de', 'tupla')
# ('esta', 'es', 'un', 'ejemplo', 'de', 'tupla')
# ['de', 'ejemplo', 'es', 'esta', 'tupla', 'un']

# %% [markdown]
# # Diccionario

# %%
menu = {"Papas Fritas": 1, "Refresco": 2, "Hamburguesa": 5, "cafe": 5}

# %%
print(menu)
# Out:
# {'Papas Fritas': 1, 'Refresco': 2, 'Hamburguesa': 5, 'cafe': 5}

# %%
for key in menu:
    print(key, menu[key])
# Out:
# Papas Fritas 1
# Refresco 2
# Hamburguesa 5
# cafe 5

# %%
for i in menu:
    print(i, menu[i])
# Out:
# Papas Fritas 1
# Refresco 2
# Hamburguesa 5
# cafe 5

# %%
for key in menu:
    print(key)
# Out:
# Papas Fritas
# Refresco
# Hamburguesa
# cafe

# %%
type(menu)
# Out:
# dict

# %%
menu[key]=10
print(menu)
# Out:
# {'Papas Fritas': 1, 'Refresco': 2, 'Hamburguesa': 5, 'cafe': 10}

# %%
menu

# %%
menu["Refresco"]= "CocaCola"
print(menu)
# Out:
# {'Papas Fritas': 1, 'Refresco': 'CocaCola', 'Hamburguesa': 5, 'cafe': 5}

# %%
del menu['Hamburguesa']

# %%
menu = {'Papas Fritas': 1, 'Tipo de Papa': ["francesa", "Western"], 'Refresco': 'CocaCola', 'Hamburguesa': 5, 'cafe': 5}
print(menu)
# Out:
# {'Papas Fritas': 1, 'Tipo de Papa': ['francesa', 'Western'], 'Refresco': 'CocaCola', 'Hamburguesa': 5, 'cafe': 5}

# %%
for i in menu:
    print(i, menu[i])
# Out:
# Papas Fritas 1
# Tipo de Papa ['francesa', 'Western']
# Refresco CocaCola
# Hamburguesa 5
# cafe 5

# %%
type(menu)
# Out:
# dict

# %%
menu.delete["cafe"]

# %%
menu.pop("cafe")

# %%
menu

# %%
menu.pop("Papas Fritas")

# %%
del menu["Refresco"]

# %%
menu

# %%
del menu.Hamburguesa
